# %% [markdown]
# 1.⁠ ⁠Introduction: waas ish de datesatz, was ish sporblem, wie wird das glöst (random forest) und was das genau heisst
# 2.⁠ ⁠⁠exploratory data analysis: Data loading, Data cleaning, beschreiben was alles in dem Datensatz enthalten ist, nützliche Plots eventuel
# 3.⁠ ⁠⁠preprocessing: encoding falls nötig, in training und test set aufteilen
# 4.⁠ ⁠⁠modelling teil, also das mit random forest dings machen - alles mit training set, accuracy und so weiter berechnen, wichtige Plots oder so
# 5.⁠ ⁠⁠Results - das gleiche wie 4. einfach mit test set
# 6.⁠ ⁠⁠Discussion und conclusion - Resultate erklären und vlt noch mit anderen Sachen vergleichen, artikel und so
